# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./samsung_table_ud.csv')

# %%
df
# Out:
#    code        date      lstm  ...  hk_youtube  suka_youtube  change
# 0  5930  2021-09-15  75550.37  ...           1             1       1
# 1  5930  2021-09-16      1.00  ...           1             1      -1
# 2  5930  2021-09-17      1.00  ...           1             1       1
# 3  5930  2021-09-23      1.00  ...           1             1       0
# 4  5930  2021-09-24      1.00  ...          -1             1       0
# 5  5930  2021-09-27     -1.00  ...          -1             1       1
# 6  5930  2021-09-28      1.00  ...          -1             1      -1
# 7  5930  2021-09-29      1.00  ...          -1             1      -1
# 8  5930  2021-09-30     -1.00  ...           1             1       0
# 9  5930  2021-10-01     -1.00  ...           1             1      -1
#
# [10 rows x 14 columns]

# %%
df['sum'] =  df['lstm'] + df['arima'] + df['fbprophet'] + df['RL'] + df['mail_news'] + df['mail_news_nsi'] + df['asia_news'] + df['asia_news_nsi'] + df['sampro_youtube'] + df['hk_youtube'] + df['suka_youtube']

# %%
df['sum']
# Out:
# 0    228668.69
# 1         6.00
# 2         5.00
# 3         3.00
# 4        -1.00
# 5        -5.00
# 6         0.00
# 7         1.00
# 8        -3.00
# 9         1.00
# Name: sum, dtype: float64

# %%
df['ratio'] = df['sum'] / 11

# %%
df['ratio'][1:]
# Out:
# 1    0.545455
# 2    0.454545
# 3    0.272727
# 4   -0.090909
# 5   -0.454545
# 6    0.000000
# 7    0.090909
# 8   -0.272727
# 9    0.090909
# Name: ratio, dtype: float64
