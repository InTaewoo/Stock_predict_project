# %% [markdown]
# --------- youtube__ 자막가져오기--

# %%
! pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-11.0.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 7.6 MB/s eta 0:00:011
# Installing collected packages: pytube
# Successfully installed pytube-11.0.1

# %%
from pytube import YouTube

# %%
video_url = 'https://www.youtube.com/watch?v=r6Qw9RzaCvI'
yt = YouTube(video_url)

# %%
dir(yt)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
#  'publish_date',
#  'rating',
#  'register_on_complete_callback',
#  'register_on_progress_callback',
#  'stream_monostate',
#  'streaming_data',
#  'streams',
#  'thumbnail_url',
#  'title',
#  'use_oauth',
#  'vid_info',
#  'video_id',
#  'views',
#  'watch_html',
#  'watch_url']

# %%
print("[영상 제목]", yt.title)  # 영상제목
print("[영상 게시자]", yt.author) # 영상 게시자
print("[조회수]", yt.views)
print("[평균평점]", yt.rating) # 평균 평점
print("[영상길이(초)]", yt.length)
print("[연령제한여부]", yt.age_restricted)
print("[영상 설명]", yt.description) # 영상 설명
print("[썸네일URL]", yt.thumbnail_url) # 썸네일 url 주소
print('[날짜]', yt.publish_date)
# Out:
# [영상 제목] 삼성전자·SK하이닉스 급락 떨어지는 칼날 잡아라? / 삼성전자, SK하이닉스, 원달러환율 / 이승조 다인경제 대표 / 투자의 맥 / 진짜전략 / 한국경제TV
# [영상 게시자] 한국경제TV
# [조회수] 337530
# [평균평점] 4.881281
# [영상길이(초)] 1268
# [연령제한여부] False
# [영상 설명] 앵커 : 하경민
#
# 출연자 : 이승조 다인경제 대표
#
# 시장이 중요힌 변곡점에 있다라고 말씀해주셨습니다. 삼성전자, 외국인이 끌어올릴 수 있을건가가 관건이더러고 멀씀해 주셨는데 끌어올릴 뻔 하다가 요즘에는 외국인을 중심으로 순매도 물량이 급격하게 출외가 되면서 좀 내려오고 있습니다. 기관도 여기에 가세를 하고 있는 상황인데 지금의 흐름, 그렇다면 흐름 자체가 바뀌었다고 봐야하나요?
#
# 00:00 오프닝
# 04:20 반도체
# 13:58 옵션 만기일 파생시장 전망
# 16:30 삼전, 하이닉스 추세
# 19:15 향후 전략
#
# △대한민국의 경제를 보세요!
# △빠르고 정확한 경제·증권 뉴스와 파트너스들의 분석진단을 24시간 전해드립니다.
# △구독좋아요 그리고 알람설정하세요!
#
# #삼성전자 #SK하이닉스 #반도체 #원달러환율 #시가총액 #외국인매도 #외국인매수 #수급 #원달러 #환율 #출발증시 #하경민 #이승조 #미증시 #美증시 #국내증시 #매수전략 #매도전략
#
# ◇ 한국경제TV 유튜브 구독
# http://bit.ly/2sOQXqQ
#
# ◇ 한국경제TV 유튜브 라이브
# https://www.youtube.com/c/hkwowtv/live
#
# ◇ 한국경제TV
# -홈페이지 http://www.wowtv.co.kr
# -플러스친구 https://pf.kakao.com/_xbcxlxgd
# -트위터 http://www.twitter.com/hkwowtv
# -페이스북 http://www.facebook.com/hkwowtv
#
#
# -편성정보: http://bit.ly/2xX9neg
# -------------------------------------------------
#
# ◆◇ 한국경제TV 패밀리 채널을 구독하세요!
# -가치를 더하는 뉴스 `한국경제TV 뉴스` https://youtube.com/한국경제TV뉴스
# -주식은 `와우넷` https://youtube.com/와우넷w
# -주식 교육은 '와우파' https://bit.ly/2YAVk8t
# -국민 주식앱 "주식창" https://youtube.com/stockw
# -똑똑한 베트남·글로벌 비즈 정보 `한경 K-VINA` http://bit.ly/2JrvJK1
# -언제까지 저축만 할래? `돈립만세` https://youtube.com/돈립만세
# [썸네일URL] https://i.ytimg.com/vi/x7to5CTAU4I/hqdefault.jpg
# [날짜] 2021-08-12 00:00:00

# %%
yt.captions.all()
# Out:
# <ipython-input-36-a5eb83d31a96>:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   yt.captions.all()
# [<Caption lang="Korean (auto-generated)" code="a.ko">]

# %%
caption = yt.captions.get_by_language_code('a.ko')
# Out:
# <ipython-input-44-eb5810e8e870>:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('a.ko')

# %%
caption.xml_captions
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '<?xml version="1.0" encoding="utf-8" ?><timedtext format="3">\n<head>\n<ws id="0"/>\n<ws id="1" mh="2" ju="0" sd="3"/>\n<wp id="0"/>\n<wp id="1" ap="6" ah="20" av="100" rc="2" cc="40"/>\n</head>\n<body>\n<w t="0" id="1" wp="1" ws="1"/>\n<p t="510" d="11159" w="1"><s ac="196">그점</s><s t="270" ac="232"> 오늘</s><s t="1020" ac="207"> 시랑은</s><s t="1560" ac="226"> 뭐</s><s t="1830" ac="208"> 중요한</s><s t="2610" ac="255"> 의미를</s><s t="3060" ac="242"> 몇가지</s><s t="3660" ac="199"> 갖는다고</s><s t="4110" ac="224"> 가야</s><s t="4380" ac="251"> 되죠</s></p>\n<p t="5749" d="5920" w="1" a="1">\n</p>\n<p t="5759" d="9811" w="1"><s ac="143">이</s><s t="31" ac="233"> 코스피가</s><s t="871" ac="166"> 일단은</s><s t="1831" ac="251"> 2005</s><s t="2430" ac="144"> 2010</s><s t="3151" ac="135"> 의</s><s t="3271" ac="219"> 50</s><s t="3660" ac="200"> 라인을</s><s t="4250" ac="151"> 돌파했다</s><s t="5250" ac="212"> 며</s><s t="5370" ac="131"> 4</s></p>\n<p t="11659" d="3911" w="1" a="1">\n</p>\n<p t="11669" d="8010" w="1"><s ac="152">그것이</s><s t="271" ac="252"> 지금</s><s t="630" ac="248"> 굉장히</s><s t="1441" ac="252"> 중요한</s><s t="1861" ac="252"> 의미를</s><s t="2160" ac="255"> 갖는다</s><s t="2670" ac="244"> 일으키고</s><s t="3030" ac="237"> 있고</s></p>\n<p t="15560" d="4119" w="1" a="1">\n</p>\n<p t="15570" d="10099" w="1"><s ac="130">어찌나</s><s t="450" ac="143"> 간</s><s t="
# %%
import re

# %%
def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
  cleantext = re.sub(cleanr, '', raw_html)
  return cleantext

# %%
aa =str(caption.xml_captions)

# %%
text=str(cleanhtml(aa)).replace('\n','')

# %%
text
# Out:
# '그점 오늘 시랑은 뭐 중요한 의미를 몇가지 갖는다고 가야 되죠이 코스피가 일단은 2005 2010 의 50 라인을 돌파했다 며 4그것이 지금 굉장히 중요한 의미를 갖는다 일으키고 있고어찌나 간 외국인이 이제 돌아 왔느냐 이게 의문이 줘돼지 외국인들이 1조 3천억 을 사는 있는 배경이나 결국은 우리나라삼성전자가 굉장히 좋아져서 그래스 냐 아니면 지금의 이제 달러 인덱스가93 까지 내려가면서 우리나라 통화 실질적으로 만이가 되진 않았지만 예1,190원 때 까지 와서 그런데 결국은 딸라 를 팔아 가지고 우리나라의팔고즉 원화를 살 수밖에 없는 이런 이치에 있기 때문 와 자산의 대학 이런기대가 있었는 거고 결국 삼성전자를 어떻게 해석하느냐에 따라서 다른 것같은데 저는 정도의 이 부분이 되게 좋다고 생각합니다인텔이 라는게 인체 라는게 누구를 손을 잡아준 냐에 따라서 대만 하고한국의 운명이 결정이 되는 이런 순간이 다 결국은 이제 인 테디 그리고지금의 7 화로에 어떻게 보면 파우더리 수주를 한국으로 주느냐 아니면대만 호주 냐에 따라서 이 그 1리에 어떤 격차는 굉장히 많이 벌어질것이고 어 결국은 이제 삼성전자가여기서 오늘 지면 고점을 넘었는데 새로운 6만원대 를 넘어가는 야 기로에있다 이렇게 본다 그래서 사실은 지금 의 오늘까지 음식으로 굉장히긍정적인 요소들이 굉장히 받나요근데 이게 부분적으로 삼성 자가 5% 6 벗은지 오른 날 다음날에그게 연결이 잘 안됐다 말이야 고른 것들도 우리 가면 고려해 봐야 되는데자반지금 현재 시장은 이쪽으로 딱 돈을 빨려 들어갔고 다른 쪽은 조정이나왔으니까 2명에 나오면서 상승 했으니까3 성장을 추첨 하면 또 이쪽에 조정 봣더니 싸지 하고 따라서 보니까 더좋은 이룬 자리다저를 이렇게 보였어요 나 어 지금 뭐 삼성전자 빨리 긴 하지만 에긍정적인 시장 흐름이 좀 이어질 것이다 라고 이야기를 좀 해 주셨고어기면 등 4편이 바라보는 오늘의 시장 어떻게 정도 보셨어요시장이 사실 요즘 뭐 별 재미가 없죠사실 어떻게 보면 되게 개인들의 어떻게 되는거 아니에요기술적 반등 장에서는 ce 머리 제 수익 내기가 쉽습니다뭐 안 됐던 게 쉽게 말씀드려서 지난번 조커로 나사 때 어떻게 3을19일그때부터 에서 17 따라 민 한올 달 까지는 이제 뭐 아무 막말로 이야기해서 암 그 마치그러다가 써가며 느뭐 2차전지 뿐만 아니고 뭐냐 지금 일간 계획적 녹아기술적 반 너 
많이 오른 자리에서 들어간것도 아니잖아 라는 생각이 살짝되거든요어이 계획인가 죄가 발정 에는 지금 삼성전자 가지고 사막 원에서 지금58,000원 왔잖아요 내가 나 근데 지금 코롤라 뗄 해서 지금 따블못가면 봐 보거든요 주식들이 어괜찮아요 근데 삼성 자리 이렇게 많이 썼다그 저는 지금 이제 외국인들이관망 하다가 이제 손바뀜이 나는데 에 삼성 대문 빵 하고 있다 이렇게 폰저그 3 단자만 이제 여 치고 올라갈 거에요더 삼성전자 만에 또 그래서 옮기게 써요 그래서 이제 여기 많이 찾기때문에 랜드 상습 가능성이 있고 한 6만 4천원 정도 까지 올라갈 것같습니다 어 다른 주식 또는 그때까지 좀 재미없지 않을까 이렇게 보이죠하기사 코스피 시장에서 삼성전자의 돈이 몰리고 그 쪽만 움직인다 그런데다른 종목 특강 별로 재미가 없는건 뭐 기장 사실 잘 없는 깨지고있는데요우리 김 대 법대 편의 봤을 때 외국인 에 어떻게 돌아 오는걸 봐요쇼 뭐 본격적으로 돌아오기는 좀 어렵다고 거에요 예삼성전자는 다른 주시오 다룹니다 던 주시오 다른 것은 우리나라 시가총액이전체 시장에서 20% 이상 가지고 있는 거 기 때문이고삼성도 다른 주식등을 원래 실적이나 추구 에 의해서종 개가 되지만 삼성전자는 여기에 프로스 매크로 지표 매크로 지표가포함된다 그럼 지금 현재는 매끄러운 지표가 달러 가 떨어지고 있는 이런상황이니까 달 은 지금 현재 우리나라의 동 팔아 가지 달 을 사면 예잘나가 손 해야만 손에 손에 인 상황에서 삼성 저를 못 팔게 돼 있는 거아닙니까그렇다면 삼성전자 진짜로 파운드리 업체 에서 대만의 그 tsmc 를완전히 격차를 확 줄일 수 있는 이번 계기를 가져갈 수 있느냐 자신을그래요 인천 이라는 데가 상 정자를 손 딱 들어 준 순간에 시 양으로완전히 바뀐다 고 봐요이건 그 기본적으로 3 정의 지금까지 133조 에 hb 명월이 투자를염두에 두고 있는 이런 상황에서 이건 일들이 벌어져 있기 때문에 나는만약에 3점을 내가 이렇게 올라온다면 오히려 지금은 여기에 수애 되는중소 영주들의 움직임들이 아주 예절의 뭐 는 대통령도 얘기했던 소 부장관련주들이 지금 최근에 많이 큰 들었는데이것때문에 또 한번 아주 급하게 올라올 수 있는 기회가 되지 않겠느냐그렇다면 삼성전자 그래 올라와 줘라3 좀 더 올라 주면 오히려 삼성 저보다 더 많이 수익이 나는 조기분명히 튀어나올 것이다그러면 그 쪽을 우리는 노려야 되지 작은 적은 자본으로 가지고 외국인들하고 같이 편성해서 외국인들이 기다릴 때 여러분을 기다릴 수가 있느냐요즘 불과 지금 많이 3개월 동안 삼성을 들고 있던 사람들은 굉장히 지금 이제 피가 마르는 이런 시작으로음들을 보였다는 왜 다른데서 지금은 주 제약바이오 이런데서 따 올라고따따블 않은데요 지금 현재 자기는 본전도 알아서 헤매고 있었던 이런 생각을 하면 내앞으로 와 짠맛 1호 일정 부음 다음에 만약에 시인은 있는 상황이 나오게되면 여러분들은 그것을 또 감 내야 ...

# %%
fw = open('0901_suka.txt', 'w')
fw.write(text)
fw.close()
